# %% [markdown]
# ## 서울시에서 공개한 코로나19 발생동향 분석
# * http://www.seoul.go.kr/coronaV/coronaStatus.do

# %%
# 필요한 라이브러리를 불러옵니다.
import pandas as pd
import numpy as np

# %%
# 크롤링으로 가져올 url 주소를 입력합니다.
# 판다스 크롤링 가능한 사이트 알아보는 법: 크롬에서 오른쪽 클릭하여 인스펙트로 소스 코드를 본다. <table> 로 보이는 데이터는 거의 판다스로 읽을 수 있다.
url = "http://www.seoul.go.kr/coronaV/coronaStatus.do"
url
# Out:
# 'http://www.seoul.go.kr/coronaV/coronaStatus.do'

# %%
# 판다스의 read_html 을 통해 위 url에 있는 불러옵니다.
table = pd.read_html(url)

# %%
# read_html 은 사이트 내의 html 태그를 불러옵니다.

table[0]
# Out:
#      소계  해외접촉관련  송파구교회관련  강서구요양시설관련  강남구사무실관련  강남구사무실K빌딩  강남구역삼동모임  리치웨이관련  \
# 0  1574     337       18         23        26          6        13     122
#
#    부천시쿠팡관련  관악구사무실관련  이태원클럽관련  구로구콜센터관련  타 시·도확진자접촉자   기타  경로확인중
# 0       24        13      139        98           53  540    162

# %%
# table 변수 안에 있는 table 태그의 값을 하나씩 읽어보며 확진자 목록이 있는 테이블을 가져옵니다.

table[1]
# Out:
#                                                    0
# 0  < 신종 코로나바이러스 감염증 예방 국민 행동수칙 >○ 기침 등 호흡기 증상이 있을...

# %%
# 미리보기 합니다.
# table 하나씩 보면서 4번 table 에 확진자 정보가 있어 가져오기로..

df = table[4]

# %%
# 마지막 확진일을 파일명에 써주기 위해 . 을 _ 로 변경합니다.
# 확장자와 구분이 쉽게 되도록 _ 로 변경합니다. 
last_day = df.loc[0,"확진일"]
last_day = last_day.replace(".","_")
last_day
# Out:
# '7_26_'

# %%
# 파일명을 만들어 줍니다.
# file_name

file_name = f"seoul-covid19-{last_day}.csv"
file_name
# Out:
# 'seoul-covid19-7_26_.csv'

# %%
# csv 파일로 저장합니다. 
# index column 생성하지 않는 것으로 csv 파일 따로 저장
df.to_csv(file_name, index = False)

# %%
# 제대로 저장되었는지 확인합니다.
pd.read_csv(file_name)
# Out:
#         연번     환자    확진일  거주지     여행력         접촉력         조치사항
# 0     1574  14172  7.26.  송파구       -  송파구 확진자 접촉        서울의료원
# 1     1573  14173  7.26.  강동구      미국    해외 접촉 추정        보라매병원
# 2     1572  14165  7.26.  종로구       -  송파구 확진자 접촉        서울의료원
# 3     1571  14175  7.26.  관악구     필리핀    해외 접촉 추정        보라매병원
# 4     1570  14171  7.26.  용산구     이라크    해외 접촉 추정        서울의료원
# ...    ...    ...    ...  ...     ...         ...          ...
# 1569     5      9  1.31.  성북구       -       #5 접촉    서울의료원(퇴원)
# 1570     4      7  1.30.  마포구  중국 우한시       해외 접촉    서울의료원(퇴원)
# 1571     3      6  1.30.  종로구       -       #3 접촉  서울대학교병원(퇴원)
# 1572     2      5  1.30.  중랑구  중국 우한시       해외 접촉    서울의료원(퇴원)
# 1573     1      2  1.24.  강서구  중국 우한시       해외 접촉  국립중앙의료원(퇴원)
#
# [1574 rows x 7 columns]

# %%
conda install -c conda-forge jupyter_contrib_nbextensions
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.8.2
#   latest version: 4.8.3
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /Users/yejinhwang/opt/anaconda3
#
#   added / updated specs:
#     - jupyter_contrib_nbextensions
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     conda-4.8.3                |   py37hc8dfbb8_1         3.0 MB  conda-forge
#     jupyter_contrib_core-0.3.3 |             py_2          15 KB  conda-forge
#     jupyter_contrib_nbextensions-0.5.1|           py37_0        19.5 MB  conda-forge
#     jupyter_highlight_selected_word-0.2.0|        py37_1000          13 KB  conda-forge
#     jupyter_latex_envs-1.4.4   |        py37_1000         746 KB  conda-forge
#     jupyter_nbextensions_configurator-0.4.1|   py37hc8dfbb8_1         470 KB  conda-forge
#     python_abi-3.7             |          1_cp37m           4 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        23.7 MB
#
# The following NEW packages will be INSTALLED:
#
#   jupyter_contrib_c~ conda-forge/noarch::jupyter_contrib_core-0.3.3-py_2
#   jupyter_contrib_n~ conda-forge/osx-64::jupyter_contrib_nbextensions-0.5.1-py37_0
#   jupyter_highlight~ conda-forge/osx-64::jupyter_highlight_selected_word-0.2.0-py37_1000
#   jupyter_latex_envs conda-forge/osx-64::jupyter_latex_envs-1.4.4-py37_1000
#   jupyter_nbextensi~ conda-forge/osx-64::jupyter_nbextensions_configurator-0.4.1-py37hc8dfbb8_1
#   python_abi         conda-forge/osx-64::python_abi-3.7-1_cp37m
#
# The following packages will be UPDATED:
#
#   conda                       pkgs/main::conda-4.8.2-py37_0 --> conda-forge::conda-4.8.3-py37hc8dfbb8_1
#
#
#
# Downloading and Extracting Packages
# jupyter_contrib_nbex | 19.5 MB   | ##################################### | 100%
# conda-4.8.3          | 3.0 MB    | ##################################### | 100%
# jupyter_highlight_se | 13 KB     | ##################################### | 100%
# jupyter_latex_envs-1 | 746 KB    | ##################################### | 100%
# jupyter_nbextensions | 470 KB    | ##################################### | 100%
# jupyter_contrib_core | 15 KB     | ##################################### | 100%
# python_abi-3.7       | 4 KB      | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: / b''
# | b''
# / b'Enabling: jupyter_nbextensions_configurator\n- Writing config: /Users/yejinhwang/opt/anaconda3/etc/jupyter\n    - Validating...\n      jupyter_nbextensions_configurator 0.4.1 \x1bOK\x1b\nEnabling notebook nbextension nbextensions_configurator/config_menu/main...\nEnabling tree nbextension nbextensions_configurator/tree_tab/main...\n'
# / b'[I 14:10:42 InstallContribNbextensionsApp] jupyter contrib nbextension install --sys-prefix\n[I 14:10:42 InstallContribNbextensionsApp] Installing jupyter_contrib_nbextensions nbextension files to jupyter data directory\n[I 14:10:42 InstallContribNbextensionsApp] Installing /Users/yejinhwang/opt/anaconda3/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/rubberband -> rubberband\n[I 14:10:42 InstallContribNbextensionsApp] Making directory: /Users/yejinhwang/opt/anaconda3/share/jupyter/nbextensions/rubberband/\n[I 14:10:42 InstallContribNbextensionsApp] Copying: /Users/yejinhwang/opt/anaconda3/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/rubberband/icon.png -> /Users/yejinhwang/opt/anaconda3/share/jupyter/nbextensions/rubberband/icon.png\n[I 14:10:42 InstallContribNbextensionsApp] Copying: /Users/yejinhwang/opt/anaconda3/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/rubberband/main.css -> /Users/yejinhwang/opt/anaconda3/share/jupyter/nbextensions/rubberband/main.css\n[I 14:10:42 InstallContribNbextensionsApp] Copying: /Users/yejinhwang/opt/anaconda3/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/rubberband/readme.md -> /Users/yejinhwang/opt/anaconda3/share/jupyter/nbextensions/rubberband/readme.md\n[I 14:10:42 InstallContribNbextensionsApp] Copying: /Users/yejinhwang/opt/anaconda3/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/rubberband/main.js -> /Users/yejinhwang/opt/anaconda3/share/jupyter/nbextensions/rubberband/main.js\n[I 14:10:42 InstallContribNbextensionsApp] Copying: /Users/yejinhwang/opt/anaconda3/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/rubberband/rubberband.yaml -> /Users/yejinhwang/opt/anaconda3/share/jupyter/nbextensions/rubberband/rubberband.yaml\n[I 14:10:42 InstallContribNbextensionsApp] - Validating: \x1bOK\x1b\n[I 14:10:42 InstallContribNbextensionsApp] Installing /Users/yejinhwang/opt/anaconda3/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/scroll_down -> scroll_down\n[I 14:10:42 InstallContribNbextensionsApp] Making directory: /Users/yejinhwang/opt/anaconda3/share/jupyter/nbextensions/scroll_down/\n[I 14:10:42 InstallContribNbextensionsApp] Copying: /Users/yejinhwang/opt/anaconda3/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/scroll_down/icon.png -> /Users/yejinhwang/opt/anaconda3/share/jupyter/nbextensions/scroll_down/icon.png\n[I 14:10:42 InstallContribNbextensionsApp] Copying: /Users/yejinhwang/opt/anaconda3/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/scroll_down/config.yaml -> /Users/yejinhwang/opt/anaconda3/share/jupyter/nbextensions/scroll_down/config.yaml\n[I 14:10:42 InstallContribNbextensionsApp] Copying: /Users/yejinhwang/opt/anaconda3/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/scroll_down/readme.md -> /Users/yejinhwang/opt/anaconda3/share/jupyter/nbextensions/scroll_down/readme.md\n[I 14:10:42 InstallContribNbextensionsApp] Copying: /Users/yejinhwang/opt/anaconda3/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/scroll_down/main.js -> /Users/yejinhwang/opt/anaconda3/share/jupyter/nbextensions/scroll_down/main.js\n[I 14:10:42 InstallContribNbextensionsApp] - Validating: \x1bOK\x1b\n[I 14:10:42 InstallContribNbextensionsApp] Installing /Users/yejinhwang/opt/anaconda3/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/hinterland -> hinterland\n[I 14:10:42 InstallContribNbextensionsApp] Making directory: /Users/yejinhwang/opt/anaconda3/share/jupyter/nbextensions/hinterland/\n[I 14:10:42 InstallContribNbextensionsApp] Copying: /Users/yejinhwang/opt/anaconda3/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/hinterland/hinterland.yaml -> /Users/yejinhwang/opt/anaconda3/share/jupyter/nbextensions/hinterland/hinterland.yaml\n[I 14:10:42 InstallContribNbextensionsApp] Copying: /Users/yejinhwang/opt/ana ...
# done
#
# Note: you may need to restart the kernel to use updated packages.
